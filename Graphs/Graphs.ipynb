# %%
import pymysql

connector = pymysql.connect(user='dev', password='ax2',host='127.0.0.1',port=3307,db='pythonexam')
cursor = connector.cursor()

query = ('SELECT country, total_cases from corona20200511 WHERE LENGTH(total_cases) > 5 and not country = %s and not country = %s and not country = %s and not country = %s and not country = %s and not country = %s and not country = %s and not country = %s')
where_not = "North America", "Asia", "South America", "Europe", "World", "Total:", "Africa", "Oceania"
cursor.execute(query, where_not)

countries = []
total_cases = [] 
for country, totalcases in cursor:
    countries.append(country)
    total_cases.append(totalcases)
cursor.close()
connector.close()

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(50,50))
ax = figure.add_axes([0,0,1,1])
sorted_total = sorted(total_cases, key=len)
print(sorted_total)
ax.bar(countries, sorted_total )

ax.set_title("Total Cases Of Corona virus", fontsize=80)
ax.set_xlabel("Country", fontsize=50)
ax.set_xticklabels(countries, rotation=90, fontsize=50)
ax.set_ylabel("Total_cases", fontsize=50)
ax.set_yticklabels(sorted_total, fontsize=50)
plt.show()
# Out:
# ['68,848', '67,724', '67,307', '53,449', '42,788', '41,014', '35,022', '30,941', '30,344', '29,559', '28,866', '27,679', '26,670', '23,906', '23,822', '23,623', '22,996', '18,198', '16,492', '16,206', '15,882', '15,777', '15,691', '15,648', '15,588', '14,265', '11,086', '11,063', '10,909', '10,513', '10,347', '10,176', '10,015', '82,918', '82,901', '68,848', '67,307', '67,161', '53,081', '42,627', '39,048', '33,460', '30,334', '30,305', '29,559', '28,866', '27,581', '26,322', '23,336', '22,996', '22,973', '22,520', '18,198', '16,477', '15,996', '15,871', '15,777', '15,362', '15,232', '14,657', '14,032', '11,063', '10,874', '10,794', '10,429', '10,347', '10,114', '10,015', '268,143', '223,060', '221,344', '219,070', '176,970', '171,999', '163,510', '138,657', '109,286', '264,663', '219,183', '219,070', '209,688', '176,970', '171,879', '162,699', '138,657', '107,603', '1,369,157', '1,367,638']
