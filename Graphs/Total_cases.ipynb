# %%
import pymysql

connector = pymysql.connect(user='dev', password='ax2',host='127.0.0.1',port=3306,db='pythonexam')
cursor = connector.cursor()

query = ('SELECT country, total_cases from corona20200511 WHERE LENGTH(total_cases) > 5 and not country = %s and not country = %s and not country = %s and not country = %s and not country = %s and not country = %s and not country = %s and not country = %s and not country = %s')
where_not = "North America", "Asia", "South America", "Europe", "World", "Total:", "Africa", "Oceania", "South Africa"
cursor.execute(query, where_not)

countries = []
total_cases = [] 
for country, totalcases in cursor:
    countries.append(country)
    total_cases.append(totalcases)
cursor.close()
connector.close()
print(countries)
print(total_cases)
# Out:
# ['USA', 'Spain', 'Russia', 'UK', 'Italy', 'France', 'Germany', 'Brazil', 'Turkey', 'Iran', 'Canada', 'Peru', 'India', 'Belgium', 'Netherlands', 'Saudi Arabia', 'Mexico', 'Pakistan', 'Switzerland', 'Ecuador', 'Chile', 'Portugal', 'Sweden', 'Belarus', 'Singapore', 'Ireland', 'Qatar', 'UAE', 'Israel', 'Poland', 'Austria', 'Japan', 'Bangladesh', 'Ukraine', 'Romania', 'Indonesia', 'Philippines', 'Colombia', 'S. Korea', 'Denmark', 'Dominican Republic', 'Serbia', 'China', 'China', 'USA', 'Spain', 'UK', 'Italy', 'Russia', 'France', 'Germany', 'Brazil', 'Turkey', 'Iran', 'Canada', 'Peru', 'India', 'Belgium', 'Netherlands', 'Saudi Arabia', 'Mexico', 'Pakistan', 'Switzerland', 'Ecuador', 'Chile', 'Portugal', 'Sweden', 'Singapore', 'Ireland', 'Belarus', 'Qatar', 'UAE', 'Israel', 'Poland', 'Austria', 'Japan', 'Romania', 'Ukraine', 'Bangladesh', 'Indonesia', 'Colombia', 'S. Korea', 'Philippines', 'Denmark', 'Dominican Republic', 'Serbia', 'USA', 'Spain', 'Russia', 'UK', 'Italy', 'France', 'Germany', 'Brazil', 'Turkey', 'Iran', 'Canada', 'Peru', 'India', 'Belgium', 'Netherlands', 'Saudi Arabia', 'Mexico', 'Pakistan', 'Switzerland', 'Ecuador', 'Chile', 'Portugal', 'Sweden', 'Belarus', 'Singapore', 'Ireland', 'Qatar', 'UAE', 'Israel', 'Poland', 'Austria', 'Japan', 'Bangladesh', 'Ukraine', 'Romania', 'Indonesia', 'Philippines', 'Colombia', 'S. Korea', 'Denmark', 'Dominican Republic', 'Serbia', 'China', 'China', 'USA', 'Spain', 'UK', 'Italy', 'Russia', 'France', 'Germany', 'Brazil', 'Turkey', 'Iran', 'Canada', 'Peru', 'India', 'Belgium', 'Netherlands', 'Saudi Arabia', 'Mexico', 'Pakistan', 'Switzerland', 'Ecuador', 'Chile', 'Portugal', 'Sweden', 'Singapore', 'Ireland', 'Belarus', 'Qatar', 'UAE', 'Israel', 'Poland', 'Austria', 'Japan', 'Romania', 'Ukraine', 'Bangladesh', 'Indonesia', 'Colombia', 'S. Korea', 'Philippines', 'Denmark', 'Dominican Republic', 'Serbia', 'USA', 'Spain', 'Russia', 'UK', 'Italy', 'France', 'Germany', 'Brazil', 'Turkey', 'Iran',
520', '18,198', '16,492', '16,206', '15,871', '15,777', '15,691', '15,648', '15,362', '14,265', '11,086', '11,063', '10,909', '10,513', '10,347', '10,114', '82,918', '82,901', '1,367,638', '264,663', '219,183', '219,070', '209,688', '176,970', '171,879', '162,699', '138,657', '107,603', '68,848', '67,307', '67,161', '53,081', '42,627', '39,048', '33,460', '30,334', '30,305', '29,559', '28,866', '27,581', '26,322', '23,336', '22,996', '22,973', '22,520', '18,198', '16,477', '15,996', '15,871', '15,777', '15,362', '15,232', '14,657', '14,032', '11,063', '10,874', '10,794', '10,429', '10,347', '10,114']

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(50,50))
ax = figure.add_axes([0,0,1,1])
sorted_total = sorted(total_cases, key=len)
#print(sorted_total)
mylist = list(dict.fromkeys(countries))
mylistb = list(dict.fromkeys(sorted_total))
newlist = [w.replace(',', '') for w in mylistb]
#mylist = sorted(mylist, key=len)
mylist.sort()
ax.bar(mylist, newlist[60:16:-1])
print(newlist[60:16:-1])

ax.set_title("Total Cases Of Corona virus", fontsize=80)
ax.set_xlabel("Country", fontsize=50)
ax.set_xticklabels(countries, rotation=90, fontsize=50)
ax.set_ylabel("Total_cases", fontsize=50)
ax.set_yticklabels(newlist[60:16:-1], fontsize=50)
plt.show()
# Out:
# ['1367638', '1367963', '209688', '107603', '138657', '162699', '171879', '176970', '219070', '219183', '221344', '264663', '10429', '10794', '10874', '14032', '14657', '15232', '15996', '16477', '22973', '23336', '30334', '33460', '53081', '67161', '82901', '82918', '10114', '10347', '10513', '10909', '11063', '11086', '14265', '15362', '15648', '15691', '15777', '15871', '16206', '16492', '18198']

# %%
import matplotlib.pyplot as plt
mylist = list(dict.fromkeys(countries))
mylistb = list(dict.fromkeys(total_cases))
print(mylist)
print(mylistb)
plt.bar(mylist, mylistb[0:43], width=0.5, align='center')
# Out:
# ['USA', 'Spain', 'Russia', 'UK', 'Italy', 'France', 'Germany', 'Brazil', 'Turkey', 'Iran', 'Canada', 'Peru', 'India', 'Belgium', 'Netherlands', 'Saudi Arabia', 'Mexico', 'Pakistan', 'Switzerland', 'Ecuador', 'Chile', 'Portugal', 'Sweden', 'Belarus', 'Singapore', 'Ireland', 'Qatar', 'UAE', 'Israel', 'Poland', 'Austria', 'Japan', 'Bangladesh', 'Ukraine', 'Romania', 'Indonesia', 'Philippines', 'Colombia', 'S. Korea', 'Denmark', 'Dominican Republic', 'Serbia', 'China']
# ['1,367,963', '264,663', '221,344', '219,183', '219,070', '176,970', '171,879', '162,699', '138,657', '107,603', '68,848', '67,307', '67,259', '53,449', '42,627', '39,048', '35,022', '30,941', '30,305', '29,559', '28,866', '27,581', '26,322', '23,906', '23,822', '22,996', '22,520', '18,198', '16,492', '16,206', '15,871', '15,777', '15,691', '15,648', '15,362', '14,265', '11,086', '11,063', '10,909', '10,513', '10,347', '10,114', '82,918', '82,901', '1,367,638', '209,688', '67,161', '53,081', '33,460', '30,334', '23,336', '22,973', '16,477', '15,996', '15,232', '14,657', '14,032', '10,874', '10,794', '10,429']
# <BarContainer object of 43 artists>
