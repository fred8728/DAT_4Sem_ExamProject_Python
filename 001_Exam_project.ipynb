# %%
import bs4 
import requests
import pandas as pd 
from tabulate import tabulate
import numpy as np
import re

url = 'https://www.worldometers.info/coronavirus/'
html_text = requests.get(url)

html_text.raise_for_status()
print('Status', html_text)

soup = bs4.BeautifulSoup(html_text.text, 'html.parser')
#print(soup.prettify())

name_of_class = soup.tr.text.strip()
#print(name_of_class)

data = []
something = soup.select('div tbody tr td')
for some in something:
    #print(some.getText())
    
    country = some.getText()
    
    cleaned = re.sub(r"\n", "", country)

    data.append(cleaned)
print(data)

#numpy = np.array([data])        
#print(numpy)
# Out:
# Status <Response [200]>
# ['North America', '1,321,020', '+1,983', '76,901', '+127', '234,975', '1,009,144', '17,297', '', '', '', '', 'North America', 'Europe', '1,481,677', '+11,766', '142,377', '+234', '560,330', '778,970', '16,938', '', '', '', '', 'Europe', 'Asia', '579,036', '+6,197', '20,201', '+123', '307,881', '250,954', '5,314', '', '', '', '', 'Asia', 'South America', '224,738', '+464', '11,298', '+30', '78,397', '135,043', '9,938', '', '', '', '', 'South America', 'Africa', '48,186', '+111', '1,850', '+2', '16,393', '29,943', '129', '', '', '', '', 'Africa', 'Oceania', '8,437', '+23', '116', '+1', '7,283', '1,038', '29', '', '', '', '', 'Australia/Oceania', '', '721', '', '15', '', '645', '61', '4', '', '', '', '', '', 'World', '3,663,815', '+20,544', '252,758', '+517', '1,205,904', '2,205,153', '49,649', '470', '32.4', '', '', 'All', 'USA', '1,213,010', '+175', '69,925 ', '+4', '188,068', '955,017', '16,050', '3,665', '211', '7,462,597', '22,545', 'North America', 'Spain', '248,301', '', '25,428 ', '', '151,633', '71,240', '2,254', '5,311', '544', '1,932,455', '41,332', 'Europe', 'Italy', '211,938', '', '29,079 ', '', '82,879', '99,980', '1,479', '3,505', '481', '2,191,403', '36,244', 'Europe', 'UK', '190,584', '', '28,734 ', '', 'N/A', '161,506', '1,559', '2,807', '423', '1,291,591', '19,026', 'Europe', 'France', '169,462', '', '25,201 ', '', '51,371', '92,890', '3,696', '2,596', '386', '1,100,228', '16,856', 'Europe', 'Germany', '166,199', '+47', '6,993 ', '', '135,100', '24,106', '1,949', '1,984', '83', '2,547,052', '30,400', 'Europe', 'Russia', '155,370', '+10,102', '1,451 ', '+95', '19,865', '134,054', '2,300', '1,065', '10', '4,460,357', '30,564', 'Europe', 'Turkey', '127,659', '', '3,461 ', '', '68,166', '56,032', '1,384', '1,514', '41', '1,171,138', '13,886', 'Asia', 'Brazil', '108,620', '+354', '7,367 ', '+24', '45,815', '55,438', '8,318', '511', '35', '339,552', '1,597', 'South America', 'Iran', '99,970', '+1,323', '6,340 ', '+63', '80,475', '13,155', '2,685', '1,190', '75', '519,543', '6,186', 'Asia', 'Canada', '60,772', '', '3,854 ', '', '26,017', '30,901', '557', '1,610', '102', '919,368', '24,359', 'North America', 'Belgium', '50,509', '+242', '8,016 ', '+92', '12,441', '30,052', '646', '4,358', '692', '456,194', '39,362', 'Europe', 'Peru', '47,372', '', '1,344 ', '', '14,427', '31,601', '694', '1,437', '41', '385,492', '11,692', 'South America', 'India', '46,476', '+39', '1,571 ', '+5', '12,849', '32,056', '', '34', '1', '1,191,946', '864', 'Asia', 'Netherlands', '40,770', '', '5,082 ', '', 'N/A', '35,438', '683', '2,379', '297', '235,909', '13,768', 'Europe', 'Ecuador', '31,881', '', '1,569 ', '', '3,433', '26,879', '159', '1,807', '89', '80,171', '4,544', 'South America', 'Switzerland', '30,009', '+28', '1,784 ', '', '25,200', '3,025', '141', '3,467', '206', '286,403', '33,092', 'Europe', 'Saudi Arabia', '28,656', '', '191 ', '', '4,476', '23,989', '143', '823', '5', '365,093', '10,487', 'Asia', 'Portugal', '25,524', '', '1,063 ', '', '1,712', '22,749', '143', '2,503', '104', '450,000', '44,132', 'Europe', 'Mexico', '24,905', '+1,434', '2,271 ', '+117', '15,938', '6,696', '378', '193', '18', '100,041', '776', 'North America', 'Sweden', '22,721', '', '2,769 ', '', '4,074', '15,878', '455', '2,250', '274', '119,500', '11,833', 'Europe', 'Ireland', '21,772', '', '1,319 ', '', '13,386', '7,067', '93', '4,409', '267', '169,377', '34,302', 'Europe', 'Pakistan', '21,501', '+560', '486 ', '+10', '5,782', '15,233', '111', '97', '2', '222,404', '1,007', 'Asia', 'Chile', '20,643', '', '270 ', '', '10,415', '9,958', '464', '1,080', '14', '214,131', '11,202', 'South America', 'Singapore', '19,410', '+632', '18 ', '', '1,457', '17,935', '22', '3,318', '3', '143,919', '24,600', 'Asia', 'Belarus', '17,489', '', '103 ', '', '3,259', '14,127', '92', '1,851', '11', '211,369', '22,369', 'Europe', 'Qatar', '17,142', '+951', '12 ', '', '1,924', '15,206', '72', '5,950', '4', '109,762', '38,098', 'Asia', 'Israel', '16,268', '+22', '237 ', '+2', ' ...

# %%
soup = bs4.BeautifulSoup(r.text, 'html.parser')
table = soup.find_all('table')[0] 
df = pd.read_html(str(table))
print( tabulate(df[0], headers='keys', tablefmt='pretty') )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c261a2927e6e> in <module>
# ----> 1 soup = bs4.BeautifulSoup(r.text, 'html.parser')
#       2 table = soup.find_all('table')[0]
#       3 df = pd.read_html(str(table))
#       4 print( tabulate(df[0], headers='keys', tablefmt='pretty') )
#
# NameError: name 'r' is not defined

# %%
import pymysql
from sqlalchemy import create_engine
connection_str = pymysql.connect(user='dev', password='ax2',host='127.0.0.1',port=3307,db='test') 
engine = create_engine(connection_str)

df.to_sql('worldometer',con=engine, if_exists='append', index = False)
print(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-552cd4e7a007> in <module>
#       4 engine = create_engine(connection_str)
#       5
# ----> 6 df.to_sql('worldometer',con=engine, if_exists='append', index = False)
#       7 print(df.dtypes)
#
# AttributeError: 'list' object has no attribute 'to_sql'
