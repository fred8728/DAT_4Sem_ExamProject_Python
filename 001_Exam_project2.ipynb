# %%
import bs4 
import requests
import pandas as pd 
from tabulate import tabulate
import numpy as np
import re

url = 'https://www.worldometers.info/coronavirus/'
html_text = requests.get(url)

html_text.raise_for_status()
#print('Status', html_text)

soup = bs4.BeautifulSoup(html_text.text, 'html.parser')
#print(soup.prettify())

name_of_class = soup.tr.text.strip()
#print(name_of_class)

data = []
something = soup.select('div tbody tr td')
for some in something:
    #print(some.getText())
    
    country = some.getText()
    
    cleaned = re.sub(r"\n", "", country)
    cleanedr2 = re.sub(r"\+", "", cleaned)
    #print(cleaned)
    data.append(cleanedr2)
#print(data)
numpy = np.array({})
for temp in range(0,len(data),13):
    numpy = (data[temp:temp+12])
    print(data[temp:temp+12])
    insertVariblesIntoTable(data[temp],data[temp+1],data[temp+2],data[temp+3],data[temp+4],data[temp+5],data[temp+6],data[temp+7],data[temp+8],data[temp+9],data[temp+10],data[temp+11],)
# Out:
# ['North America', '1,472,075', '29,325', '88,845', '1,755', '295,309', '1,087,921', '17,986', '', '', '', '']
# Record inserted successfully into corona table
# MySQL connection is closed
# ['Europe', '1,605,838', '24,582', '151,765', '1,251', '647,209', '806,864', '14,354', '', '', '', '']
# Record inserted successfully into corona table
# MySQL connection is closed
# ['South America', '297,930', '15,755', '15,392', '815', '103,599', '178,939', '10,093', '', '', '', '']
# Record inserted successfully into corona table
# MySQL connection is closed
# ['Asia', '650,796', '15,965', '21,834', '333', '358,548', '270,414', '5,023', '', '', '', '']
# Record inserted successfully into corona table
# MySQL connection is closed
# ['Africa', '61,983', '2,933', '2,232', '71', '21,627', '38,124', '222', '', '', '', '']
# Record inserted successfully into corona table
# MySQL connection is closed
# ['Oceania', '8,525', '17', '118', '', '7,599', '808', '22', '', '', '', '']
# ...

# %%
import mysql.connector as connector
#note - install dns - pip install dnspython
import pandas as pd 
import pymysql
from sqlalchemy import create_engine #sqlalchemy helped convert strings to dates seamlessly

#Create table in database
con = pymysql.connect(user='dev', password='ax2',host='127.0.0.1',port=3306,db='pythonexam')  
cursor = con.cursor()
# .format data på table navn
query = "CREATE TABLE IF NOT EXISTS corona (Country varchar(255), Total_cases varchar(255), New_cases varchar(255), Total_deaths varchar(255), New_deaths varchar(255), Total_recov varchar(255), Active_cases varchar(255), Serious_critical varchar(255), Total_cases_1mio varchar(255), Deaths_1miopop varchar(255), Total_tests varchar(255), Tests_1miopop varchar(255))"

cursor.execute(query)
# Out:
# 0

# %%
import mysql.connector
from mysql.connector import Error

def insertVariblesIntoTable(Country, Total_cases, New_cases, Total_deaths, New_deaths, Total_recov, Active_cases, Serious_critical, Total_cases_1mio, Deaths_1miopop, Total_tests, Tests_1miopop):
    try:
        connection = mysql.connector.connect(host='localhost',
                                             database='pythonexam',
                                             user='emil'
                                             )
        cursor = connection.cursor()
        mySql_insert_query = """INSERT INTO corona (Country, Total_cases, New_cases, Total_deaths, New_deaths, Total_recov, Active_cases, Serious_critical, Total_cases_1mio, Deaths_1miopop, Total_tests, Tests_1miopop) 
                                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s) """

        recordTuple = (Country, Total_cases, New_cases, Total_deaths, New_deaths, Total_recov, Active_cases, Serious_critical, Total_cases_1mio, Deaths_1miopop, Total_tests, Tests_1miopop)
        cursor.execute(mySql_insert_query, recordTuple)
        connection.commit()
        print("Record inserted successfully into corona table")

    except mysql.connector.Error as error:
        print("Failed to insert into MySQL table {}".format(error))

    finally:
        if (connection.is_connected()):
            cursor.close()
            connection.close()
            print("MySQL connection is closed")

# %%
### DOESNT WORK 
#cnx = pymysql.connect(user='dev', password='ax2',host='127.0.0.1',port=3307,db='test') 
connection = 'mysql+pymysql://dev:ax2@localhost:3307/pythonexam'
engine = create_engine(connection)

i= 0
for index in numpy[i]:
    #Total_cases,New_cases,Total_deaths,New_deaths,Total_recov,Active_cases,Serious_critical,Total_cases_1mio,Deaths_1miopop,Total_tests,Tests_1miopop) VALUES ({})'.format(index)
    query = 'INSERT INTO corona (Country) VALUES ({})'.format(index)
    cursor.execute(query)
    con.commit()
    print(cursor)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-24-d80c47c77689> in <module>
#       7     #Total_cases,New_cases,Total_deaths,New_deaths,Total_recov,Active_cases,Serious_critical,Total_cases_1mio,Deaths_1miopop,Total_tests,Tests_1miopop) VALUES ({})'.format(index)
#       8     query = 'INSERT INTO corona (Country) VALUES ({})'.format(index)
# ----> 9     cursor.execute(query)
#      10     con.commit()
#      11     print(cursor)
#
# ~\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# ~\Anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# ...

# %%
soup = bs4.BeautifulSoup(html_text.text, 'html.parser')
table = soup.find_all('table')[0] 
df = pd.read_html(str(table))
print( tabulate(df[0], headers='keys', tablefmt='pretty') )
# Out:
# +-----+------------------------+------------+----------+-------------+-----------+----------------+-------------+------------------+------------------+---------------+------------+---------------+
# |     |     Country,Other      | TotalCases | NewCases | TotalDeaths | NewDeaths | TotalRecovered | ActiveCases | Serious,Critical | Tot Cases/1M pop | Deaths/1M pop | TotalTests | Tests/ 1M pop |
# +-----+------------------------+------------+----------+-------------+-----------+----------------+-------------+------------------+------------------+---------------+------------+---------------+
# |  0  |         World          |  3834038   | +16,656  |  265238.0   |   401.0   |   1306483.0    |   2262317   |     48210.0      |      492.0       |     34.0      |    nan     |      nan      |
# |  1  |          USA           |  1263224   |   +132   |   74809.0   |   10.0    |    213109.0    |   975306    |     15827.0      |      3816.0      |     226.0     | 8005589.0  |    24186.0    |
# ...
