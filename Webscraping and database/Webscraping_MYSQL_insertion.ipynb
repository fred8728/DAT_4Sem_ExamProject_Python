# %%
import mysql.connector as connector
#note - install dns - pip install dnspython
import pandas as pd 
import pymysql
from sqlalchemy import create_engine #sqlalchemy helped convert strings to dates seamlessly
from datetime import date
import re

#Create table in database
con = pymysql.connect(user='dev', password='ax2',host='127.0.0.1',port=3306,db='pythonexam')  
cursor = con.cursor()
# .format data på table navn
datenow = date.today()
datestring = datenow.strftime("%Y%m%d")
print(datestring)
query = "CREATE TABLE IF NOT EXISTS corona{} (Country varchar(255), Total_cases varchar(255), New_cases varchar(255), Total_deaths varchar(255), New_deaths varchar(255), Total_recov varchar(255), Active_cases varchar(255), Serious_critical varchar(255), Total_cases_1mio varchar(255), Deaths_1miopop varchar(255), Total_tests varchar(255), Tests_1miopop varchar(255))".format(datestring)
temp = query
cursor.execute(temp)
# Out:
# 20200515
# 0

# %%
import mysql.connector
from mysql.connector import Error

def insert_data(Country, Total_cases, New_cases, Total_deaths, New_deaths, Total_recov, Active_cases, Serious_critical, Total_cases_1mio, Deaths_1miopop, Total_tests, Tests_1miopop):
    try:
        connection = mysql.connector.connect(host='localhost', port=3306, database='pythonexam', user='dev',password="ax2")
        cursor = connection.cursor()
        
        query = """INSERT INTO corona{} (Country, Total_cases, New_cases, Total_deaths, New_deaths, Total_recov, Active_cases, Serious_critical, Total_cases_1mio, Deaths_1miopop, Total_tests, Tests_1miopop) 
                                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s) """.format(datestring) 
        
        record_tuple = (Country, Total_cases, New_cases, Total_deaths, New_deaths, Total_recov, Active_cases, Serious_critical, Total_cases_1mio, Deaths_1miopop, Total_tests, Tests_1miopop)
        cursor.execute(query, record_tuple)
        connection.commit()
        #print("Record inserted successfully into table")

    except mysql.connector.Error as error:
        print("Failed to insert into MySQL table {}".format(error))

    finally:
        if (connection.is_connected()):
            cursor.close()
            connection.close()
            #print("MySQL connection is closed")

# %%
import bs4 
import requests
import pandas as pd 
#from tabulate import tabulate
import numpy as np
import re

url = 'https://www.worldometers.info/coronavirus/'
html_text = requests.get(url)

html_text.raise_for_status()
#print('Status', html_text)

soup = bs4.BeautifulSoup(html_text.text, 'html.parser')
#print(soup.prettify())

name_of_class = soup.tr.text.strip()
#print(name_of_class)

data = []
something = soup.select('div tbody tr td')
for some in something:
    #print(some.getText())
    
    country = some.getText()
    
    cleaned = re.sub(r"\n", "", country)
    cleanedr2 = re.sub(r"\+", "", cleaned)
    #print(cleaned)
    data.append(cleanedr2)
#print(data)
numpy = np.array({})
for temp in range(91,len(data)-3130,13):
    numpy = (data[temp:temp+12])
    print(data[temp:temp+12])
    insert_data(data[temp],data[temp+1],data[temp+2],data[temp+3],data[temp+4],data[temp+5],data[temp+6],data[temp+7],data[temp+8],data[temp+9],data[temp+10],data[temp+11],)
# Out:
# ['World', '4,520,208', '94,553', '303,038', '5,273', '1,700,174', '2,516,996', '45,552', '580', '38.9', '', '']
# ['USA', '1,455,866', '25,519', '86,887 ', '1,690', '317,015', '1,051,964', '16,240', '4,398', '262', '10,592,913', '32,003']
# ['Spain', '272,646', '1,551', '27,321 ', '217', '186,480', '58,845', '1,376', '5,831', '584', '2,467,761', '52,781']
# ['Russia', '252,245', '9,974', '2,305 ', '93', '53,530', '196,410', '2,300', '1,728', '16', '6,188,102', '42,403']
# ['UK', '233,151', '3,446', '33,614 ', '428', 'N/A', '199,193', '1,559', '3,434', '495', '2,219,281', '32,691']
# ['Italy', '223,096', '992', '31,368 ', '262', '115,288', '76,440', '855', '3,690', '519', '2,807,504', '46,434']
# ['Brazil', '202,918', '13,761', '13,993 ', '835', '79,479', '109,446', '8,318', '955', '66', '735,224', '3,459']
# ['France', '178,870', '810', '27,425 ', '351', '59,605', '91,840', '2,299', '2,740', '420', '1,384,633', '21,213']
# ['Germany', '174,975', '877', '7,928 ', '67', '150,300', '16,747', '1,329', '2,088', '95', '3,147,771', '37,570']
# ['Turkey', '144,749', '1,635', '4,007 ', '55', '104,030', '36,712', '963', '1,716', '48', '1,508,824', '17,890']
# ['Iran', '114,533', '1,808', '6,854 ', '71', '90,539', '17,140', '2,758', '1,364', '82', '643,772', '7,665']
# ['India', '81,997', '3,942', '2,649 ', '98', '27,969', '51,379', '', '59', '2', '1,947,041', '1,411']
# ['Peru', '80,604', '4,298', '2,267 ', '98', '25,151', '53,186', '842', '2,445', '69', '587,292', '17,812']
# ['Canada', '73,401', '1,123', '5,472 ', '170', '36,091', '31,838', '502', '1,945', '145', '1,169,380', '30,983']
# ['Belgium', '54,288', '307', '8,903 ', '60', '14,111', '31,274', '407', '4,684', '768', '623,628', '53,809']
# ['Saudi Arabia', '46,869', '2,039', '283 ', '10', '19,051', '27,535', '156', '1,346', '8', '513,587', '14,752']
# ['Netherlands', '43,481', '270', '5,590  ', '28', 'N/A', '37,641', '410', '2,538', '326', '282,776', '16,503']
# ['Mexico', '40,186', '1,862', '4,220 ', '294', '26,990', '8,976', '378', '312', '33', '142,204', '1,103']
# ['Chile', '37,040', '2,659', '368 ', '22', '15,655', '21,017', '663', '1,938', '19', '325,417', '17,023']
# ['Pakistan', '35,788', '490', '770 ', '9', '9,695', '25,323', '111', '162', '3', '330,750', '1,497']
# ['Ecuador', '30,502', '16', '2,338 ', '4', '3,433', '24,731', '196', '1,729', '133', '88,923', '5,040']
# ['Switzerland', '30,463', '50', '1,872 ', '2', '27,100', '1,491', '79', '3,520', '216', '328,163', '37,918']
# ['Sweden', '28,582', '673', '3,529 ', '69', '4,971', '20,082', '351', '2,830', '349', '177,500', '17,576']
# ['Portugal', '28,319', '187', '1,184 ', '9', '3,198', '23,937', '108', '2,777', '116', '582,341', '57,111']
# ['Qatar', '28,272', '1,733', '14 ', '', '3,356', '24,902', '72', '9,813', '5', '143,938', '49,960']
# ['Belarus', '26,772', '947', '151 ', '5', '8,168', '18,453', '92', '2,833', '16', '308,156', '32,611']
# ['Singapore', '26,098', '752', '21 ', '', '5,973', '20,104', '20', '4,461', '4', '224,262', '38,333']
# ['Ireland', '23,827', '426', '1,506 ', '9', '19,470', '2,851', '69', '4,825', '305', '258,808', '52,414']
# ['UAE', '21,084', '698', '208 ', '2', '6,930', '13,946', '1', '2,132', '21', '1,560,923', '157,822']
# ['Bangladesh', '18,863', '1,041', '283 ', '14', '3,361', '15,219', '1', '115', '2', '151,930', '923']
# ['Poland', '17,615', '411', '883 ', '22', '6,696', '10,036', '160', '465', '23', '554,357', '14,647']
# ['Ukraine', '16,847', '422', '456 ', '17', '4,143', '12,248', '222', '385', '10', '202,495', '4,630']
# ['Israel', '16,579', '31', '265 ', '1', '12,521', '3,793', '62', '1,915', '31', '485,922', '56,140']
# ['Romania', '16,247', '245', '1,053 ', '17', '9,053', '6,141', '225', '845', '55', '286,217', '14,878']
# ['Austria', '16,058', '61', '626 ', '2', '14,405', '1,027', '54', '1,783', '70', '344,606', '38,262']
# ['Japan', '16,049', '', '678 ', '', '8,920', '6,451', '243', '127', '5', '223,667', '1,768']
# ['Indonesia', '16,006', '568', '1,043 ', '15', '3,518', '11,445', '', '59', '4', '173,690', '635']
# ['Colombia', '13,610', '680', '525 ', '16', '3,358', '9,727', '130', '267', '10', '165,738', '3,257']
# ['South Africa', '12,739', '665', '238 ', '19', '5,676', '6,825', '119', '215', '4', '403,018', '6,795']
# ['Kuwait', '11,975', '947', '88 ', '6', '3,451', '8,436', '175', '2,804', '21', '231,930', '54,309']
# ['Philippines', '11,876', '258', '790 ', '18', '2,337', '8,749', '77', '108', '7', '189,469', '1,729']
# ['Dominican Republic', '11,320', '124', '422 ', '13', '3,351', '7,547', '131', '1,044', '39', '47,774', '4,404']
# ['S. Korea', '10,991', '29', '260 ', '1', '9,762', '969', '55', '214', '5', '711,484', '13,877']
# ['Egypt', '10,829', '398', '571 ', '15', '2,626', '7,632', '41', '106', '6', '105,000', '1,026']
# ['Denmark', '10,713', '46', '537 ', '4', '8,805', '1,371', '35', '1,850', '93', '357,986', '61,805']
# ['Serbia', '10,374', '79', '224  ', '2', '4,084', '6,066', '22', '1,187', '26', '162,797', '18,632']
# ['Panama', '8,944', '161', '256 ', '4', '6,067', '2,621', '87', '2,073', '59', '45,873', '10,632']
# ['Czechia', '8,351', '82', '293 ', '3', '5,241', '2,817', '42', '780', '27', '334,714', '31,255']
# ['Norway', '8,196', '21', '232 ', '3', '32', '7,932', '23', '1,512', '43', '212,655', '39,226']
# ['Argentina', '7,134', '255', '353 ', '24', '2,385', '4,396', '170', '158', '8', '93,673', '2,073']
# ['Australia', '6,989', '9', '98 ', '', '6,301', '590', '18', '274', '4', '943,480', '36,999']
# ['Malaysia', '6,819', '40', '112 ', '1', '5,351', '1,356', '16', '211', '3', '271,721', '8,395']
# ['Morocco', '6,607', '95', '190 ', '2', '3,310', '3,107', '1', '179', '5', '77,922', '2,111']
# ['Algeria', '6,442', '189', '529 ', '7', '3,158', '2,755', '22', '147', '12', '6,500', '148']
# ['Bahrain', '6,198', '382', '10 ', '', '2,353', '3,835', '4', '3,643', '6', '214,084', '125,815']
# ['Finland', '6,145', '91', '287 ', '3', '4,300', '1,558', '33', '1,109', '52', '137,000', '24,726']
# ['Afghanistan', '5,639', '413', '136 ', '4', '691', '4,812', '7', '145', '3', '19,732', '507']
# ['Kazakhstan', '5,571', '154', '32 ', '', '2,531', '3,008', '31', '297', '2', '459,736', '24,484']
# ['Moldova', '5,553', '147', '194 ', '9', '2,228', '3,131', '251', '1,377', '48', '20,447', '5,069']
# ['Ghana', '5,530', '122', '24 ', '', '674', '4,832', '5', '178', '0.8', '167,704', '5,397']
# ['Nigeria', '5,162', '191', '167 ', '3', '1,180', '3,815', '7', '25', '0.8', '30,657', '149']
# ['Oman', '4,341', '322', '18 ', '1', '1,303', '3,020', '31', '850', '4', '61,000', '11,945']
# ['Luxembourg', '3,915', '11', '103 ', '', '3,665', '147', '11', '6,254', '165', '58,727', '93,816']
# ['Armenia', '3,860', '142', '49 ', '1', '1,572', '2,239', '10', '1,303', '17', '36,016', '12,154']
# ['Hungary', '3,380', '39', '436 ', '6', '1,169', '1,775', '49', '350', '45', '123,258', '12,759']
# ['Bolivia', '3,148', '184', '142 ', '14', '339', '2,667', '3', '270', '12', '7,651', '655']
# ['Iraq', '3,143', '111', '115 ', '', '2,028', '1,000', '', '78', '3', '140,573', '3,495']
# ['Thailand', '3,018', '1', '56 ', '', '2,850', '112', '61', '43', '0.8', '286,008', '4,098']
# ['Cameroon', '2,954', '154', '139 ', '3', '1,553', '1,262', '28', '111', '5', '', '']
# ['Azerbaijan', '2,879', '121', '35 ', '', '1,833', '1,011', '29', '284', '3', '214,291', '21,135']
# ['Greece', '2,770', '10', '156 ', '1', '1,374', '1,240', '24', '266', '15', '116,233', '11,152']
# ['Uzbekistan', '2,645', '33', '11 ', '', '2,136', '498', '8', '79', '0.3', '325,000', '9,710']
# ['Guinea', '2,473', '99', '15 ', '1', '895', '1,563', '18', '188', '1', '10,304', '785']
# ['Honduras', '2,255', '175', '123 ', '2', '237', '1,895', '10', '228', '12', '5,653', '571']
# ['Croatia', '2,221', '8', '94 ', '', '1,850', '277', '7', '541', '23', '50,340', '12,262']
# ['Bosnia and Herzegovina', '2,218', '37', '122 ', '2', '1,272', '824', '4', '676', '37', '45,810', '13,963']
# ['Senegal', '2,189', '84', '23  ', '2', '842', '1,324', '6', '131', '1', '24,599', '1,469']
# ['Bulgaria', '2,100', '31', '99 ', '3', '531', '1,470', '51', '302', '14', '61,711', '8,881']
# ['Ivory Coast', '1,971', '59', '24 ', '', '930', '1,017', '', '75', '0.9', '15,260', '579']
# ['Cuba', '1,830', '20', '79 ', '', '1,383', '368', '9', '162', '7', '75,142', '6,634']
# ['Sudan', '1,818', '', '90 ', '', '198', '1,530', '', '41', '2', '', '']
# ['Iceland', '1,802', '', '10 ', '', '1,780', '12', '', '5,281', '29', '55,626', '163,010']
# ['Estonia', '1,758', '7', '62 ', '1', '909', '787', '5', '1,325', '47', '67,130', '50,606']
# ['North Macedonia', '1,723', '29', '95 ', '', '1,235', '393', '21', '827', '46', '20,088', '9,642']
# ['Lithuania', '1,511', '6', '54 ', '', '934', '523', '17', '555', '20', '208,253', '76,499']
# ['New Zealand', '1,497', '', '21 ', '', '1,411', '65', '2', '310', '4', '209,613', '43,468']
# ['Slovakia', '1,477', '8', '27 ', '', '1,112', '338', '5', '271', '5', '131,910', '24,161']
# ['Slovenia', '1,464', '1', '103 ', '', '267', '1,094', '7', '704', '50', '66,678', '32,073']
# ['Guatemala', '1,342', '143', '29 ', '2', '121', '1,192', '5', '75', '2', '7,200', '402']
# ['Somalia', '1,284', '65', '53 ', '1', '135', '1,096', '2', '81', '3', '', '']
# ['Djibouti', '1,284', '16', '3 ', '', '905', '376', '', '1,300', '3', '16,647', '16,849']
# ['DRC', '1,242', '73', '50 ', '', '157', '1,035', '', '14', '0.6', '', '']
# ['Mayotte', '1,210', '67', '16 ', '2', '627', '567', '10', '4,435', '59', '5,000', '18,327']
# ['El Salvador', '1,112', '75', '23 ', '3', '405', '684', '19', '171', '4', '48,913', '7,541']
# ['Gabon', '1,104', '100', '10 ', '1', '182', '912', '13', '496', '4', '5,530', '2,485']
# ['Kyrgyzstan', '1,082', '38', '12 ', '', '735', '335', '13', '166', '2', '59,490', '9,118']
# ['Hong Kong', '1,052', '1', '4 ', '', '1,009', '39', '1', '140', '0.5', '168,291', '22,448']
# ['Tunisia', '1,032', '', '45 ', '', '759', '228', '5', '87', '4', '34,323', '2,904']
# ['Maldives', '982', '27', '4 ', '', '45', '933', '2', '1,817', '7', '11,775', '21,784']
# ['Latvia', '962', '11', '19 ', '', '627', '316', '2', '510', '10', '83,275', '44,150']
# ['Sri Lanka', '925', '32', '9 ', '', '445', '471', '1', '43', '0.4', '39,629', '1,851']
# ['Guinea-Bissau', '913', '77', '3 ', '', '26', '884', '', '464', '2', '1,500', '762']
# ['Tajikistan', '907', '106', '29 ', '6', '', '878', '', '95', '3', '', '']
# ['Cyprus', '907', '2', '17 ', '', '481', '409', '10', '751', '14', '81,942', '67,869']
# ['Albania', '898', '18', '31 ', '', '694', '173', '1', '312', '11', '11,239', '3,905']
# ['Lebanon', '886', '8', '26 ', '', '236', '624', '4', '130', '4', '56,385', '8,261']
# ['Niger', '876', '16', '50 ', '1', '677', '149', '', '36', '2', '5,723', '236']
# ['Costa Rica', '830', '15', '8 ', '1', '535', '287', '4', '163', '2', '18,388', '3,610']
# ['Mali', '779', '21', '46 ', '2', '436', '297', '', '38', '2', '2,498', '123']
# ['Burkina Faso', '773', '', '51 ', '', '592', '130', '', '37', '2', '', '']
# ['Andorra', '761', '1', '49 ', '', '596', '116', '3', '9,849', '634', '1,673', '21,653']
# ['Kenya', '758', '21', '42 ', '2', '284', '432', '1', '14', '0.8', '36,918', '687']
# ['Paraguay', '754', '14', '11 ', '', '184', '559', '', '106', '2', '18,184', '2,549']
# ['Uruguay', '724', '5', '19 ', '', '547', '158', '7', '208', '5', '31,209', '8,984']
# ['Diamond Princess', '712', '', '13 ', '', '651', '48', '4', '', '', '', '']
# ['Georgia', '667', '20', '12 ', '1', '383', '272', '6', '167', '3', '34,500', '8,648']
# ['Zambia', '654', '208', '7 ', '', '124', '523', '1', '36', '0.4', '15,487', '842']
# ['San Marino', '648', '5', '41 ', '', '172', '435', '1', '19,098', '1,208', '3,300', '97,256']
# ['Jordan', '586', '4', '9 ', '', '393', '184', '5', '57', '0.9', '131,985', '12,936']
# ['Equatorial Guinea', '583', '61', '7 ', '1', '13', '563', '', '416', '5', '854', '609']
# ['Channel Islands', '548', '', '43 ', '', '456', '49', '', '3,152', '247', '5,342', '30,725']
# ['Malta', '522', '14', '6 ', '', '443', '73', '1', '1,182', '14', '45,967', '104,105']
# ['Tanzania', '509', '', '21 ', '', '183', '305', '7', '9', '0.4', '', '']
# ['Jamaica', '509', '2', '9 ', '', '113', '387', '', '172', '3', '7,552', '2,550']
# ['Venezuela', '440', '', '10 ', '', '220', '210', '2', '15', '0.4', '525,902', '18,494']
# ['Taiwan', '440', '', '7 ', '', '383', '50', '', '18', '0.3', '68,335', '2,869']
# ['Réunion', '440', '1', ' ', '', '354', '86', '4', '491', '', '17,200', '19,211']
# ['Sierra Leone', '408', '21', '26 ', '', '97', '285', '', '51', '3', '', '']
# ['Chad', '399', '27', '46 ', '4', '83', '270', '', '24', '3', '', '']
# ['Congo', '391', '58', '15 ', '4', '87', '289', '', '71', '3', '', '']
# ['Palestine', '375', '', '2 ', '', '310', '63', '', '74', '0.4', '43,566', '8,540']
# ['Benin', '339', '12', '2 ', '', '83', '254', '', '28', '0.2', '25,471', '2,101']
# ['Isle of Man', '332', '', '23 ', '', '285', '24', '20', '3,904', '270', '3,973', '46,723']
# ['Mauritius', '332', '', '10 ', '', '322', '0', '', '261', '8', '69,773', '54,863']
# ['Montenegro', '324', '', '9 ', '', '309', '6', '2', '516', '14', '10,167', '16,188']
# ['Cabo Verde', '315', '26', '2 ', '', '67', '246', '', '567', '4', '791', '1,423']
# ['Vietnam', '312', '24', ' ', '', '260', '52', '2', '3', '', '275,000', '2,825']
# ['Rwanda', '287', '', ' ', '', '168', '119', '', '22', '', '45,140', '3,485']
# ['Ethiopia', '272', '9', '5 ', '', '108', '159', '', '2', '0.04', '45,278', '394']
# ['Nepal', '246', '3', ' ', '', '35', '211', '', '8', '', '81,685', '2,803']
# ['Togo', '238', '19', '11 ', '', '96', '131', '', '29', '1', '11,796', '1,425']
# ['Sao Tome and Principe', '235', '15', '7 ', '1', '4', '224', '', '1,072', '32', '175', '799']
# ['Haiti', '234', '15', '18 ', '', '17', '199', '', '21', '2', '1,408', '123']
# ['Madagascar', '230', '18', ' ', '', '108', '122', '1', '8', '', '5,670', '205']
# ['Liberia', '215', '2', '20 ', '', '105', '90', '', '43', '4', '', '']
# ['South Sudan', '203', '', ' ', '', '2', '201', '', '18', '', '1,247', '111']
# ['Martinique', '189', '', '14 ', '', '91', '84', '2', '504', '37', '', '']
# ['Eswatini', '187', '', '2 ', '', '51', '134', '', '161', '2', '2,262', '1,950']
# ['Faeroe Islands', '187', '', ' ', '', '187', '0', '', '3,827', '', '8,638', '176,780']
# ['Myanmar', '181', '', '6 ', '', '84', '91', '', '3', '0.1', '12,482', '229']
# ['French Guiana', '164', '11', '1 ', '', '124', '39', '', '549', '3', '', '']
# ['Uganda', '160', '21', ' ', '', '63', '97', '', '3', '', '67,559', '1,477']
# ['Guadeloupe', '155', '', '13 ', '', '109', '33', '4', '387', '32', '', '']
# ['Gibraltar', '147', '', ' ', '', '144', '3', '', '4,363', '', '4,750', '140,987']
# ['CAR', '143', '', ' ', '', '10', '133', '', '30', '', '3,498', '724']
# ['Brunei ', '141', '', '1 ', '', '134', '6', '2', '322', '2', '16,523', '37,769']
# ['Bermuda', '122', '1', '9 ', '1', '66', '47', '2', '1,959', '145', '4,691', '75,324']
# ['Cambodia', '122', '', ' ', '', '121', '1', '1', '7', '', '14,461', '865']
# ['Trinidad and Tobago', '116', '', '8 ', '', '107', '1', '', '83', '6', '2,516', '1,798']
# ['Mozambique', '115', '11', ' ', '', '35', '80', '', '4', '', '5,119', '164']
# ['Guyana', '113', '', '10 ', '', '42', '61', '3', '144', '13', '1,052', '1,337']
# ['Aruba', '101', '', '3 ', '', '93', '5', '4', '946', '28', '1,937', '18,142']
# ['Mongolia', '98', '56', ' ', '', '15', '83', '2', '30', '', '10,162', '3,100']
# ['Bahamas', '96', '2', '11 ', '', '41', '44', '1', '244', '28', '1,700', '4,323']
# ['Monaco', '96', '', '4 ', '', '87', '5', '1', '2,446', '102', '', '']
# ['Cayman Islands', '93', '7', '1 ', '', '54', '38', '3', '1,415', '15', '5,342', '81,282']
# ['Yemen', '85', '15', '12 ', '', '1', '72', '', '3', '0.4', '120', '4']
# ['Barbados', '85', '', '7 ', '', '65', '13', '4', '296', '24', '3,480', '12,110']
# ['Liechtenstein', '82', '', '1 ', '', '55', '26', '', '2,151', '26', '900', '23,605']
# ['Sint Maarten', '76', '', '15 ', '', '46', '15', '7', '1,773', '350', '329', '7,673']
# ['Libya', '64', '', '3 ', '', '28', '33', '', '9', '0.4', '3,253', '473']
# ['Malawi', '63', '', '3 ', '', '24', '36', '1', '3', '0.2', '1,363', '71']
# ['French Polynesia', '60', '', ' ', '', '59', '1', '', '214', '', '3,170', '11,285']
# ['Syria', '48', '', '3 ', '', '29', '16', '', '3', '0.2', '', '']
# ['Angola', '48', '3', '2 ', '', '14', '32', '', '1', '0.06', '6,136', '187']
# ['Macao', '45', '', ' ', '', '43', '2', '1', '69', '', '', '']
# ['Saint Martin', '39', '', '3 ', '', '30', '6', '1', '1,009', '78', '', '']
# ['Eritrea', '39', '', ' ', '', '38', '1', '', '11', '', '', '']
# ['Zimbabwe', '37', '', '4 ', '', '13', '20', '', '2', '0.3', '36,081', '2,428']
# ['Nicaragua', '25', '', '8 ', '', '7', '10', '', '4', '1', '', '']
# ['Antigua and Barbuda', '25', '', '3 ', '', '19', '3', '1', '255', '31', '183', '1,869']
# ['Botswana', '24', '', '1 ', '', '17', '6', '', '10', '0.4', '11,495', '4,888']
# ['Timor-Leste', '24', '', ' ', '', '21', '3', '', '18', '', '738', '560']
# ['Gambia', '23', '', '1 ', '', '10', '12', '', '10', '0.4', '1,341', '555']
# ['Grenada', '21', '', ' ', '', '13', '8', '4', '187', '', '1,406', '12,495']
# ['Mauritania', '20', '5', '2 ', '', '7', '11', '', '4', '0.4', '2,015', '433']
# ['Bhutan', '19', '8', ' ', '', '5', '14', '', '25', '', '12,932', '16,760']
# ['Laos', '19', '', ' ', '', '14', '5', '', '3', '', '4,092', '562']
# ['Belize', '18', '', '2 ', '', '16', '0', '', '45', '5', '1,043', '2,623']
# ['Fiji', '18', '', ' ', '', '14', '4', '', '20', '', '1,300', '1,450']
# ['New Caledonia', '18', '', ' ', '', '18', '0', '', '63', '', '5,454', '19,103']
# ['Saint Lucia', '18', '', ' ', '', '18', '0', '', '98', '', '727', '3,959']
# ['St. Vincent Grenadines', '17', '', ' ', '', '12', '5', '', '153', '', '155', '1,397']
# ['Curaçao', '16', '', '1 ', '', '14', '1', '', '98', '6', '389', '2,371']
# ['Dominica', '16', '', ' ', '', '15', '1', '', '222', '', '420', '5,834']
# ['Namibia', '16', '', ' ', '', '12', '4', '', '6', '', '2,011', '791']
# ['Burundi', '15', '', '1 ', '', '7', '7', '', '1', '0.08', '284', '24']
# ['Saint Kitts and Nevis', '15', '', ' ', '', '14', '1', '', '282', '', '327', '6,147']
# ['Falkland Islands', '13', '', ' ', '', '13', '0', '', '3,736', '', '402', '115,517']
# ['Turks and Caicos', '12', '', '1 ', '', '10', '1', '', '310', '26', '109', '2,815']
# ['Vatican City', '12', '', ' ', '', '2', '10', '', '14,981', '', '', '']
# ['Comoros', '11', '', '1 ', '', '3', '7', '', '13', '1', '', '']
# ['Montserrat', '11', '', '1 ', '', '8', '2', '1', '2,204', '200', '36', '7,212']
# ['Greenland', '11', '', ' ', '', '11', '0', '', '194', '', '1,579', '27,814']
# ['Seychelles', '11', '', ' ', '', '10', '1', '', '112', '', '', '']
# ['Suriname', '10', '', '1 ', '', '9', '0', '', '17', '2', '404', '689']
# ['MS Zaandam', '9', '', '2 ', '', '', '7', '', '', '', '', '']
# ['Papua New Guinea', '8', '', ' ', '', '8', '0', '', '0.9', '', '2,402', '268']
# ['British Virgin Islands', '7', '', '1 ', '', '4', '2', '', '232', '33', '167', '5,524']
# ['Caribbean Netherlands', '6', '', ' ', '', '6', '0', '', '229', '', '357', '13,614']
# ['St. Barth', '6', '', ' ', '', '6', '0', '', '607', '', '', '']
# ['Western Sahara', '6', '', ' ', '', '6', '0', '', '10', '', '', '']
# ['Anguilla', '3', '', ' ', '', '3', '0', '', '200', '', '', '']
# ['Lesotho', '1', '', ' ', '', '', '1', '', '0.5', '', '', '']
# ['Saint Pierre Miquelon', '1', '', ' ', '', '1', '0', '', '173', '', '', '']
